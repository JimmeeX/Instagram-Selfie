# %%
import requests
from bs4 import BeautifulSoup
import pickle
import pandas as pd
import re
import os
import json
import time

# %%
from multiprocessing import Pool

# %%
def download_instagram_json(shortcode):
    out_path = "/mnt/e/Data/selfies/instagram_json"
    out_file = shortcode + ".json"
    if not os.path.exists(os.path.join(out_path, out_file)):
        try:
            print("Processing:", shortcode)
            r  = requests.get("https://www.instagram.com/p/" + shortcode +"?__a=1")
            data = r.json()

            # Get Likes, Following, Followers and append to data
            owner_username = data["graphql"]["shortcode_media"]["owner"]["username"]
            owner_url = "https://www.instagram.com/" + owner_username
            r = requests.get(owner_url)
            soup = BeautifulSoup(r.text, "lxml")
            description = soup.find("meta", property="og:description")["content"]
            nums = re.compile(r"[+-]?\d+(?:\.\d+)?")
            res = nums.findall(description.split("-")[0])
            owner_stats = dict(zip(["followers", "following", "posts"], res))
            data["graphql"]["shortcode_media"]["owner"].update(owner_stats)

            # Save data
            with open(os.path.join(out_path, out_file), 'w') as fout:
                json.dump(data, fout)
        except Exception as e:
            print("Error:", shortcode, e)

# %%
def main():
    with open('selfie_shortcodes_10055.pkl', 'rb') as f:
        shortcodes = pickle.load(f)
    
    for shortcode in shortcodes:
        download_instagram_json(shortcode)
#     # Multiprocess images
#     with Pool(6) as p:
#         p.map(download_instagram_json, shortcodes)

# %%
if __name__ == '__main__':
    main()
# Out:
# Processing: BuTqGVSlyA5
# Error: BuTqGVSlyA5 Expecting value: line 1 column 1 (char 0)
# Processing: BuTqGT3ggr7
# Processing: BuTqGHjn3au
# Processing: BuTqGL6Fsah
# Processing: BuTqFfhATaM
# Processing: BuTqFbXljZY
# Error: BuTqFbXljZY Expecting value: line 1 column 1 (char 0)
# Processing: BuTqBz8F8cl
# Processing: BuTp_UxAVuY
# Processing: BuTp-dogaSo
# Processing: BuTp-NHFsOK
# Processing: BuTp-N3Hiu7
# Processing: BuTp8GEBj-H
# Processing: BuTp5gvgxbu
# Processing: BuTp4wvnuOD
# Processing: BuTp3kpDbTP
# Processing: BuTp3EphvPJ
# Processing: BuTo5aCl3Cj
# Processing: BuTo2DRnwvb
# Processing: BuToKG2jSr5
# Processing: BuTfEB_FloL
# Processing: BuTaSZwFvDB
# Processing: BuTRujFHG2t
# Processing: BuTRLcvnEJX
# Processing: BuTCv0hHl45
# Processing: BuS_htuFrt4
# Processing: BuS6m9cBBNd
# Processing: BuSWLINlyJH
# Processing: BuQmsw1n9ko
# Processing: BuGsUQqH8bh
# Processing: BuDxoMwA_aw
# Processing: Bt-YaAhgxqf
# Processing: BtL-SFAFgxT
# Processing: BtIaWTmn75K
# Processing: BtGZmppgVRB
# Processing: Bs9ZvrrlYkP
# Processing: BoRYYYShVhg
# Processing: BnWaHLMgsB5
# Processing: BhhH5EbAO6K
# Processing: BeXgSEaHEGd
# Processing: BuTqHDAnD65
# Error: BuTqHDAnD65 Expecting value: line 1 column 1 (char 0)
# Processing: BuTqHFfFHBT
# Processing: BuTqHHfnthd
# Processing: BuTqG6Zhmwu
# Processing: BuTqGtrBwBH
# Processing: BuTqGvxAxkx
# Processing: BuTqGsfA9OM
# Processing: BuTqGqgASDZ
# Error: BuTqGqgASDZ Expecting value: line 1 column 1 (char 0)
# Processing: BuTqGmLgD2H
# Processing: BuTqGlfBGm4
# Processing: BuTqGh0hXNi
# Processing: BuTqGX-na3h
# Processing: BuTqGTFgaZD
# Processing: BuTqGRxg3EI
# Error: BuTqGRxg3EI Expecting value: line 1 column 1 (char 0)
# Processing: BuTqGJrFOaA
# Processing: BuTqGHQhkgX
# Processing: BuTqGHzBk-K
# Processing: BuTqGLznlgm
# Processing: BuTqGKtntpm
# Processing: BuTqGJEAz5Y
# Processing: BuTqGFuFoPt
# Processing: BuTqGEkg8vR
# Error: BuTqGEkg8vR Expecting value: line 1 column 1 (char 0)
# Processing: BuTqGJunyMW
# Processing: BuTqF81lYua
# Error: BuTqF81lYua Expecting value: line 1 column 1 (char 0)
# Processing: BuTqGBLg4YL
# Processing: BuTqFnLnezK
# Processing: BuTqFkwDLy7
# Processing: BuTqFAihIHl
# Processing: BuTqFDPAqXw
# Processing: BuTqE7cl9qr
# Processing: BuTqEzXh7aU
# Processing: BuTqEs_BcZ_
# Processing: BuTqEjKlCm0
# Processing: BuTqEA1luJ5
# Processing: BuTqD3MnAls
# Processing: BuTqD1_AAqL
# Processing: BuTqCvygcAT
# Processing: BuTqCminH3K
# Processing: BuTqCVBHRjc
# Processing: BuTqB6iA3K2
# Processing: BuTqAe0FSGc
# Processing: BuTp_jngT1j
# Processing: BuTp-img_om
# Processing: BuTp9AUHhso
# Processing: BuTp28BnNYS
# Processing: BuTp6qxB0oq
# Error: BuTp6qxB0oq Expecting value: line 1 column 1 (char 0)
# Processing: BuTp6f0FVcz
# Processing: BuTpy5Hgt7l
# Processing: BuTpkGuAiEN
# Processing: BuTphivAce6
# Processing: BuTohhxlMp1
# Processing: BuTmG77gGdz
# Processing: BuTlx0lFgvt
# Error: BuTlx0lFgvt Expecting value: line 1 column 1 (char 0)
# Processing: BuTjNcBFigK
# Processing: BuTRbW1HLt4
# Processing: BuTJ8WDnQIu
# Processing: BuRHWtYB8yp
# Processing: BuRBy2rnFYS
# Processing: BuODNQ6HPn0
# Processing: BuM9U2KATPF
# Processing: BuLt_4oHBWK
# Processing: BuD_MxElyjp
# Processing: Bt-8gEklAzM
# Processing: Bttt9lhHIdF
# Processing: BtV7iAtHIkg
# Processing: BsK2_ddFjWs
# Processing: BsA1_qZljkp
# Processing: Bez37qUHKkb
# Processing: BaOw1mrAull
# Processing: BJe4A_Sj540
# Processing: 6XepP2D4ve
# Processing: BuTqGB6H_7t
# Processing: BuTqF2hAuMi
# Processing: BuTqF6sDO5B
# Processing: BuTqF4zAS9W
# Processing: BuTqF10gKcD
# Processing: BuTqF6sFnoO
# Processing: BuTqF4sBG04
# Processing: BuTqFy0Bs40
# Processing: BuTqFvFFQU6
# Processing: BuTqFnfgL1u
# Processing: BuTqFpGn0Zn
# Processing: BuTqFroF68H
# Processing: BuTqFnzhtTB
# Processing: BuTqFk0HkRS
# Processing: BuTqFkbFOxc
# Processing: BuTqFdVgM0n
# Processing: BuTqFapBSQd
# Processing: BuTqFcRlV87
# Processing: BuTqFVvhKfM
# Processing: BuTqFWbFUhZ
# Processing: BuTqFLEngVG
# Processing: BuTqFFpl2Q3
# Error: BuTqFFpl2Q3 Expecting value: line 1 column 1 (char 0)
# Processing: BuTqFERn6HO
# Processing: BuTqE_qg5En
# Processing: BuTqE-fAHmu
# Processing: BuTqFC7ncCu
# Processing: BuTqE3VHBPS
# Processing: BuTqE3PF8rO
# Processing: BuTqE8uhxq4
# Error: BuTqE8uhxq4 Expecting value: line 1 column 1 (char 0)
# Processing: BuTqEpdBe4p
# Processing: BuTqEhaFAwb
# Processing: BuTqEWJHG0v
# Processing: BuTqEGiH639
# Processing: BuTqEGUnQmb
# Processing: BuTplEUgFdg
# Processing: BuTqDKTBoFj
# Processing: BuTqCgJgaKW
# Error: BuTqCgJgaKW Expecting value: line 1 column 1 (char 0)
# Processing: BuTqCRjH-TQ
# Processing: BuTqCA1jxI5
# Processing: BuTqA3IFvH9
# Processing: BuTp_EJlWyp
# Processing: BuTp-7qFcP7
# Processing: BuTpvPxlmBT
# Error: BuTpvPxlmBT Expecting value: line 1 column 1 (char 0)
# Processing: BuTptQGFq4G
# Processing: BuTpm8Xnf1o
# Processing: BuTpNipnhBg
# Processing: BuTou53BYMz
# Error: BuTou53BYMz Expecting value: line 1 column 1 (char 0)
# Processing: BuTf_F0BrDp
# Processing: BuTZ9jsA0Iu
# Processing: BuTSkLXhRDc
# Processing: BuTPQ0HnQnp
# Processing: BuTJcualaBy
# Processing: BuSySdFHzz-
# Processing: BuRrsPclBMa
# Processing: BuOcw2lFmhz
# Processing: BuL1zHzATKY
# Processing: BuJfyqGnQlA
# Processing: BuJCWvBhJEk
# Processing: BuEvQTEF5RM
# Processing: BuBpXPwACvk
# Processing: Bt-VyX9FRJT
# Processing: Bt-Eqj0Fgzx
# Processing: Bt9kXWSHKjy
# Processing: BtfgZAWFRoI
# Processing: BtOKwZlFwTa
# Processing: Bs-xHKkBbYY
# Processing: Bs-Un1oADfQ
# Processing: BszqOIZD_xi
# Processing: Bl_MU_-gB72
# Processing: BjrqhL8ge8t
# Processing: BY5k4fqA7wD
# Processing: BOu80_ljnf_
# Processing: BuTp6PMHTw_
# Processing: BuTqErVhlHZ
# Error: BuTqErVhlHZ Expecting value: line 1 column 1 (char 0)
# Processing: BuTqEnYDz4g
# Processing: BuTqEm9ldT0
# Processing: BuTqEoHn2qJ
# Processing: BuTqEjqDnOC
# Processing: BuTqEiYgtQh
# Processing: BuTqEe-FbuI
# Processing: BuTqEZrnsld
# Processing: BuTqEY1APNC
# Error: BuTqEY1APNC Expecting value: line 1 column 1 (char 0)
# Processing: BuTqEIGAUds
# Error: BuTqEIGAUds Expecting value: line 1 column 1 (char 0)
# Processing: BuTqEJ4HFlM
# Processing: BuTqEFtH3pd
# Processing: BuTqEF7FxDc
# Processing: BuTqEEMHF1_
# Processing: BuTqEBbBpiG
# Error: BuTqEBbBpiG Expecting value: line 1 column 1 (char 0)
# Processing: BuTqEBgnDq3
# Processing: BuTqD5pnplH
# Processing: BuTqD4DhHV3
# Processing: BuTqD5xlq3l
# Processing: BuTp8WJjxHm
# Processing: BuTqDw4AQxD
# Processing: BuTqDqqF6OD
